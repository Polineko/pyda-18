# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/statistics_basics/horse_data.csv', 
names=["surgery?", "Age", "Hospital Number", "rectal temperature", "pulse", "respiratory rate", "temperature of extremities", 
"peripheral pulse", "mucous membranes", "capillary refill time", "pain", "peristalsis", "abdominal distension", "nasogastric tube",
"nasogastric reflux", "nasogastric reflux PH", "rectal examination", "abdomen", "packed cell volume", "total protein", "abdominocentesis appearance",
"abdomcentesis total protein", "outcome", "surgical lesion?", "type of lesion1", "type of lesion2", "type of lesion3", "cp_data"])

# %%
data = data[["surgery?", "Age", "rectal temperature", "pulse", "respiratory rate", "temperature of extremities", "pain", "outcome"]]
data.head()
# Out:
#   surgery?  Age rectal temperature pulse respiratory rate  \
# 0        2    1              38.50    66               28
# 1        1    1               39.2    88               20
# 2        2    1              38.30    40               24
# 3        1    9              39.10   164               84
# 4        2    1              37.30   104               35
#
#   temperature of extremities pain outcome
# 0                          3    5       2
# 1                          ?    3       3
# 2                          1    3       1
# 3                          4    2       2
# 4                          ?    ?       2

# %%
data2 = data.replace('?', np.NaN)

# %%
data2
# Out:
#     surgery?  Age rectal temperature pulse respiratory rate  \
# 0          2    1              38.50    66               28
# 1          1    1               39.2    88               20
# 2          2    1              38.30    40               24
# 3          1    9              39.10   164               84
# 4          2    1              37.30   104               35
# ..       ...  ...                ...   ...              ...
# 295        1    1                NaN   120               70
# 296        2    1              37.20    72               24
# 297        1    1              37.50    72               30
# 298        1    1              36.50   100               24
# 299        1    1               37.2    40               20
#
#     temperature of extremities pain outcome
# 0                            3    5       2
# 1                          NaN    3       3
# 2                            1    3       1
# 3                            4    2       2
# ...

# %%
data3 = data2.apply(pd.to_numeric)

# %%
data3
# Out:
#      surgery?  Age  rectal temperature  pulse  respiratory rate  \
# 0         2.0    1                38.5   66.0              28.0
# 1         1.0    1                39.2   88.0              20.0
# 2         2.0    1                38.3   40.0              24.0
# 3         1.0    9                39.1  164.0              84.0
# 4         2.0    1                37.3  104.0              35.0
# ..        ...  ...                 ...    ...               ...
# 295       1.0    1                 NaN  120.0              70.0
# 296       2.0    1                37.2   72.0              24.0
# 297       1.0    1                37.5   72.0              30.0
# 298       1.0    1                36.5  100.0              24.0
# 299       1.0    1                37.2   40.0              20.0
#
#      temperature of extremities  pain  outcome
# 0                           3.0   5.0      2.0
# 1                           NaN   3.0      3.0
# 2                           1.0   3.0      1.0
# ...

# %%
data3.describe()
# Out:
#          surgery?         Age  rectal temperature       pulse  \
# count  299.000000  300.000000          240.000000  276.000000
# mean     1.397993    1.640000           38.167917   71.913043
# std      0.490305    2.173972            0.732289   28.630557
# min      1.000000    1.000000           35.400000   30.000000
# 25%      1.000000    1.000000           37.800000   48.000000
# 50%      1.000000    1.000000           38.200000   64.000000
# 75%      2.000000    1.000000           38.500000   88.000000
# max      2.000000    9.000000           40.800000  184.000000
#
#        respiratory rate  temperature of extremities       pain     outcome
# count        242.000000                  244.000000  245.00000  299.000000
# mean          30.417355                    2.348361    2.95102    1.551839
# std           17.642231                    1.045054    1.30794    0.737187
# min            8.000000                    1.000000    1.00000    1.000000
# ...

# %%
data3['Age'].mode()[0]
# Out:
# 1

# %%
data3['surgery?'].mode()[0]
# Out:
# 1.0

# %%
data3['rectal temperature'].mode()[0]
# Out:
# 38.0

# %%
data3['pulse'].mode()[0]
# Out:
# 48.0

# %%
data3['respiratory rate'].mode()[0]
# Out:
# 20.0

# %%
data3['temperature of extremities'].mode()[0]
# Out:
# 3.0

# %%
data3['pain'].mode()[0]
# Out:
# 3.0

# %%
data3['outcome'].mode()[0]
# Out:
# 1.0

# %%
data3['pain'].fillna(data3.groupby('outcome')['pain'].transform('median'), inplace = True)

# %%
data3
# Out:
#      surgery?  Age  rectal temperature  pulse  respiratory rate  \
# 0         2.0    1                38.5   66.0              28.0
# 1         1.0    1                39.2   88.0              20.0
# 2         2.0    1                38.3   40.0              24.0
# 3         1.0    9                39.1  164.0              84.0
# 4         2.0    1                37.3  104.0              35.0
# ..        ...  ...                 ...    ...               ...
# 295       1.0    1                 NaN  120.0              70.0
# 296       2.0    1                37.2   72.0              24.0
# 297       1.0    1                37.5   72.0              30.0
# 298       1.0    1                36.5  100.0              24.0
# 299       1.0    1                37.2   40.0              20.0
#
#      temperature of extremities  pain  outcome
# 0                           3.0   5.0      2.0
# 1                           NaN   3.0      3.0
# 2                           1.0   3.0      1.0
# ...

# %%
data3['temperature of extremities'].fillna(data3.groupby('outcome')['temperature of extremities'].transform('median'), inplace = True)

# %%
data3['respiratory rate'].fillna(data3.groupby('outcome')['respiratory rate'].transform('median'), inplace = True)

# %%
data3['pulse'].fillna(data3.groupby('outcome')['pulse'].transform('median'), inplace = True)

# %%
data3['rectal temperature'].fillna(data3.groupby('outcome')['rectal temperature'].transform('median'), inplace = True)

# %%
data3['surgery?'].fillna(data3.groupby('outcome')['surgery?'].transform('median'), inplace = True)

# %%
data3['outcome'].fillna(data3.groupby(['pain', 'temperature of extremities'])['outcome'].transform('median'), inplace = True)

# %%
data4 = data3.dropna()

# %%
data4.describe()
# Out:
#          surgery?        Age  rectal temperature       pulse  \
# count  299.000000  299.00000          299.000000  299.000000
# mean     1.397993    1.64214           38.161873   71.826087
# std      0.490305    2.17730            0.656410   27.840688
# min      1.000000    1.00000           35.400000   30.000000
# 25%      1.000000    1.00000           37.900000   48.500000
# 50%      1.000000    1.00000           38.100000   64.000000
# 75%      2.000000    1.00000           38.500000   88.000000
# max      2.000000    9.00000           40.800000  184.000000
#
#        respiratory rate  temperature of extremities        pain     outcome
# count        299.000000                  299.000000  299.000000  299.000000
# mean          29.588629                    2.361204    2.996656    1.551839
# std           16.001930                    0.967578    1.199828    0.737187
# min            8.000000                    1.000000    1.000000    1.000000
# ...

# %%
q1 = data4["Age"].quantile(0.25)
q3 = data4["Age"].quantile(0.75)
iqr = q3-q1
lower_bound = q1 - (1.5 + iqr)
upper_bound = q3 + (1.5 + iqr)
remove_outliers = data4[data4["Age"].between(lower_bound, upper_bound, inclusive=True)]
data4.append(remove_outliers, ignore_index=True).drop_duplicates(keep=False).head() #выбросы не удаляем, в рамках нормы
# Out:
#     surgery?  Age  rectal temperature  pulse  respiratory rate  \
# 3        1.0    9                39.1  164.0              84.0
# 9        2.0    9                38.3   90.0              24.0
# 13       2.0    9                38.0   92.0              28.0
# 16       1.0    9                38.1  128.0              36.0
# 23       1.0    9                38.3  130.0              60.0
#
#     temperature of extremities  pain  outcome
# 3                          4.0   2.0      2.0
# 9                          1.0   5.0      1.0
# 13                         1.0   1.0      2.0
# 16                         3.0   4.0      2.0
# 23                         2.0   2.0      1.0

# %%
q1 = data4["rectal temperature"].quantile(0.25)
q3 = data4["rectal temperature"].quantile(0.75)
iqr = q3-q1
lower_bound = q1 - (1.5 + iqr)
upper_bound = q3 + (1.5 + iqr)
remove_outliers = data4[data4["rectal temperature"].between(lower_bound, upper_bound, inclusive=True)]
data4.append(remove_outliers, ignore_index=True).drop_duplicates(keep=False)
# Out:
#      surgery?  Age  rectal temperature  pulse  respiratory rate  \
# 44        1.0    1                35.4  140.0              24.0
# 258       1.0    1                40.8   72.0              42.0
#
#      temperature of extremities  pain  outcome
# 44                          3.0   4.0      3.0
# 258                         3.0   2.0      2.0

# %%
q1 = remove_outliers["pulse"].quantile(0.25)
q3 = remove_outliers["pulse"].quantile(0.75)
iqr = q3-q1
lower_bound = q1 - (1.5 + iqr)
upper_bound = q3 + (1.5 + iqr)
remove_outliers1 = remove_outliers[remove_outliers["pulse"].between(lower_bound, upper_bound, inclusive=True)]
remove_outliers.append(remove_outliers1, ignore_index=True).drop_duplicates(keep=False)#выбросы не удаляем, в рамках нормы
# Out:
#      surgery?  Age  rectal temperature  pulse  respiratory rate  \
# 3         1.0    9                39.1  164.0              84.0
# 23        1.0    9                38.3  130.0              60.0
# 39        1.0    9                39.2  146.0              96.0
# 41        2.0    9                39.0  150.0              72.0
# 54        1.0    9                38.6  160.0              20.0
# 62        2.0    1                38.2  130.0              16.0
# 102       1.0    9                38.0  140.0              68.0
# 133       1.0    9                38.1  136.0              48.0
# 146       1.0    1                38.3  132.0              24.0
# 253       1.0    9                38.8  184.0              84.0
# 272       1.0    9                38.8  150.0              50.0
#
#      temperature of extremities  pain  outcome
# 3                           4.0   2.0      2.0
# 23                          2.0   2.0      1.0
# 39                          3.0   4.0      2.0
# ...

# %%
q1 = remove_outliers["respiratory rate"].quantile(0.25)
q3 = remove_outliers["respiratory rate"].quantile(0.75)
iqr = q3-q1
lower_bound = q1 - (1.5 + iqr)
upper_bound = q3 + (1.5 + iqr)
remove_outliers1 = remove_outliers[remove_outliers["respiratory rate"].between(lower_bound, upper_bound, inclusive=True)]
remove_outliers.append(remove_outliers1, ignore_index=True).drop_duplicates(keep=False)#выбросы не удаляем, в рамках нормы
# Out:
#      surgery?  Age  rectal temperature  pulse  respiratory rate  \
# 3         1.0    9               39.10  164.0              84.0
# 11        2.0    1               39.10   72.0              52.0
# 20        1.0    1               39.90   72.0              60.0
# 23        1.0    9               38.30  130.0              60.0
# 39        1.0    9               39.20  146.0              96.0
# 41        2.0    9               39.00  150.0              72.0
# 81        1.0    9               38.10  100.0              80.0
# 83        1.0    1               37.80   60.0              80.0
# 98        2.0    1               39.60  108.0              51.0
# 102       1.0    9               38.00  140.0              68.0
# 105       1.0    1               38.30   52.0              96.0
# 119       1.0    1               39.40   54.0              66.0
# 124       1.0    1               38.00   42.0              68.0
# 183       1.0    1               38.50  120.0              60.0
# ...

# %%
remove_outliers.describe()
# Out:
#          surgery?         Age  rectal temperature       pulse  \
# count  297.000000  297.000000          297.000000  297.000000
# mean     1.400673    1.646465           38.162290   71.595960
# std      0.490862    2.184001            0.620082   27.651152
# min      1.000000    1.000000           36.000000   30.000000
# 25%      1.000000    1.000000           37.900000   48.000000
# 50%      1.000000    1.000000           38.100000   64.000000
# 75%      2.000000    1.000000           38.500000   88.000000
# max      2.000000    9.000000           40.300000  184.000000
#
#        respiratory rate  temperature of extremities        pain     outcome
# count        297.000000                  297.000000  297.000000  297.000000
# mean          29.565657                    2.356902    2.996633    1.545455
# std           16.036379                    0.969411    1.201065    0.734379
# min            8.000000                    1.000000    1.000000    1.000000
# ...
